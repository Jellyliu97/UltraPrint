# %%
import numpy as np

#计算两个npy结尾的特征向量之间的相似度
vec1 = np.load('/root/autodl-tmp/Results/test_dataset/zyt/zyt_seg_0045_video_u.npy').ravel()
vec2 = np.load('/root/autodl-tmp/Results/test_dataset/zsx/zsx_seg_0286_video_u.npy').ravel()

sim = np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
print(sim)
# Out:
# 0.5245561
