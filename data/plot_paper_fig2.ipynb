# %%
### imapct on different time
#分开的绘图方式
import numpy as np
import matplotlib.pyplot as plt

#语音强度对比图
def plot_stacked_histogram(x_categories, y_data_list, labels=None):
    # High-quality conference colors (7 colors)
    colors = ['#2166ac','#d6604d']
    
    fig, ax = plt.subplots(figsize=(10, 6), dpi=400)
    bottom = np.zeros(len(x_categories))
    
    for i, data in enumerate(y_data_list):
        ax.bar(x_categories[i], data, bottom=bottom, color=colors[0])
        # bottom += data
        bottom = 0

    # Increase font size for all text elements
    plt.rcParams['font.size'] = 24
    plt.rcParams['font.weight'] = 'bold'
    plt.rcParams['font.serif'] = 'Times New Roman'

    # Make tick labels bigger and bold
    ax.tick_params(axis='both', which='major', labelsize=24, width=2)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontweight('bold')

    # Make axis labels bigger and bold
    ax.xaxis.label.set_size(28)
    ax.xaxis.label.set_weight('bold')
    ax.yaxis.label.set_size(28)
    ax.yaxis.label.set_weight('bold')
    # ax.errorbar(x_categories, y_data_list, yerr=y_data_list_std, fmt='none', ecolor='black', elinewidth=2, capsize=6)

    # Make legend bigger and bold
    # ax.legend(prop={'size': 14, 'weight': 'bold'})
    # ax.set_title('Stacked Histogram')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Accuracy (%)')
    ax.set_yticks(np.arange(0, 101, 20))
    # ax.set_ylim(0, 10)
    # ax.yaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.xaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.legend()
    # ax.legend(reversed(ax.get_legend_handles_labels()[0]), reversed(labels_stacked))
    
    return fig, ax

# Use existing data and add new series
# x_categories = ['10', '20', '30', '40', '50']
# y_data_list_stacked = [44.15, 24.17, 14.94, 10.90, 7.50]

x_categories = ["1", "2", "3", "4", "5"]
y_data_list_stacked = [95.17, 95.86, 95.50, 95.40, 93.64] 
# y_data_list_std= [0.30, 0.22, 0.25, 0.27, 0.33, ]
# Create the plot
fig, ax = plot_stacked_histogram(x_categories, y_data_list_stacked)

# Save the figure
plt.savefig('./paper_fig/Impact_time.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
### imapct on different human posture
#分开的绘图方式
import numpy as np
import matplotlib.pyplot as plt

#语音强度对比图
def plot_stacked_histogram(x_categories, y_data_list, labels=None):
    # High-quality conference colors (7 colors)
    colors = ['#2166ac','#d6604d']
    
    fig, ax = plt.subplots(figsize=(10, 6), dpi=400)
    bottom = np.zeros(len(x_categories))
    
    for i, data in enumerate(y_data_list):
        ax.bar(x_categories[i], data, bottom=bottom, color=colors[0])
        # bottom += data
        bottom = 0

    # Increase font size for all text elements
    plt.rcParams['font.size'] = 24
    plt.rcParams['font.weight'] = 'bold'
    plt.rcParams['font.serif'] = 'Times New Roman'

    # Make tick labels bigger and bold
    ax.tick_params(axis='both', which='major', labelsize=24, width=2)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontweight('bold')

    # Make axis labels bigger and bold
    ax.xaxis.label.set_size(28)
    ax.xaxis.label.set_weight('bold')
    ax.yaxis.label.set_size(28)
    ax.yaxis.label.set_weight('bold')
    # ax.errorbar(x_categories, y_data_list, yerr=y_data_list_std, fmt='none', ecolor='black', elinewidth=2, capsize=6)

    # Make legend bigger and bold
    # ax.legend(prop={'size': 14, 'weight': 'bold'})
    # ax.set_title('Stacked Histogram')
    ax.set_xlabel('Distance (cm)')
    ax.set_ylabel('Accuracy (%)')
    ax.set_yticks(np.arange(0, 101, 20))
    # ax.set_ylim(0, 10)
    # ax.yaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.xaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.legend()
    # ax.legend(reversed(ax.get_legend_handles_labels()[0]), reversed(labels_stacked))
    
    return fig, ax

# Use existing data and add new series
# x_categories = ['10', '20', '30', '40', '50']
# y_data_list_stacked = [44.15, 24.17, 14.94, 10.90, 7.50]

x_categories = ["10", "15", "20", "25"]
y_data_list_stacked = [97.17, 97.86, 98.33, 98.33] 
# y_data_list_std= [0.30, 0.22, 0.25, 0.27, 0.33, ]
# Create the plot
fig, ax = plot_stacked_histogram(x_categories, y_data_list_stacked)

# Save the figure
plt.savefig('./paper_fig/Impact_distance.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
### imapct on different angle
#分开的绘图方式
import numpy as np
import matplotlib.pyplot as plt

#语音强度对比图
def plot_stacked_histogram(x_categories, y_data_list, labels=None):
    # High-quality conference colors (7 colors)
    colors = ['#2166ac','#d6604d']
    
    fig, ax = plt.subplots(figsize=(10, 6), dpi=400)
    bottom = np.zeros(len(x_categories))
    
    for i, data in enumerate(y_data_list):
        
        # #3个bar太粗了不好看，缩小到5个bar的宽度
        # if i == 0:
        #     n_present = len(x_categories)
        #     target_bars = 5
        #     base_width = 0.8  # typical matplotlib bar width for many categories
        #     bar_width = base_width * (n_present / target_bars)  # shrink to occupy width of 5 bars
        #     positions = np.arange(n_present)
        #     ax.set_xticks(positions)
        #     ax.set_xticklabels(x_categories)

        # ax.bar(positions[i], data, width=bar_width, bottom=0, color=colors[0])

        # ax.bar(x_categories[i], data, bottom=bottom, color=colors[0])
        ax.bar(x_categories[i], data, width= 0.5,bottom=bottom, color=colors[0])

        # # 将当前绘制的柱子宽度调整为与5个数据时相同（比如0.8）
        # bar_width = 0.8
        # # 获取刚刚绘制的柱子（最后一个patch），并设置宽度与中心位置
        # last_patch = ax.patches[-1]
        # center = last_patch.get_x() + last_patch.get_width() / 2
        # last_patch.set_width(bar_width)
        # last_patch.set_x(center - bar_width / 2)

        # bottom += data
        bottom = 0

    # Increase font size for all text elements
    plt.rcParams['font.size'] = 24
    plt.rcParams['font.weight'] = 'bold'
    plt.rcParams['font.serif'] = 'Times New Roman'

    # Make tick labels bigger and bold
    ax.tick_params(axis='both', which='major', labelsize=24, width=2)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontweight('bold')

    # Make axis labels bigger and bold
    ax.xaxis.label.set_size(28)
    ax.xaxis.label.set_weight('bold')
    ax.yaxis.label.set_size(28)
    ax.yaxis.label.set_weight('bold')
    # ax.errorbar(x_categories, y_data_list, yerr=y_data_list_std, fmt='none', ecolor='black', elinewidth=2, capsize=6)

    # Make legend bigger and bold
    # ax.legend(prop={'size': 14, 'weight': 'bold'})
    # ax.set_title('Stacked Histogram')
    ax.set_xlabel('Angle')
    ax.set_ylabel('Accuracy (%)')
    ax.set_yticks(np.arange(0, 101, 20))
    # ax.set_ylim(0, 10)
    # ax.yaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.xaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.legend()
    # ax.legend(reversed(ax.get_legend_handles_labels()[0]), reversed(labels_stacked))
    
    return fig, ax

# Use existing data and add new series
# x_categories = ['10', '20', '30', '40', '50']
# y_data_list_stacked = [44.15, 24.17, 14.94, 10.90, 7.50]

x_categories = ["-20°", "0°", "20°"]
y_data_list_stacked = [93.89, 96.46, 96.67]
# y_data_list_std= [0.29, 0.31, 0.33]
# Create the plot
fig, ax = plot_stacked_histogram(x_categories, y_data_list_stacked)

# Save the figure
plt.savefig('./paper_fig/Impact_angle.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
### imapct on different human posture
#分开的绘图方式
import numpy as np
import matplotlib.pyplot as plt

#语音强度对比图
def plot_stacked_histogram(x_categories, y_data_list, labels=None):
    # High-quality conference colors (7 colors)
    colors = ['#2166ac','#d6604d']
    
    fig, ax = plt.subplots(figsize=(10, 6), dpi=400)
    bottom = np.zeros(len(x_categories))
    
    for i, data in enumerate(y_data_list):
        ax.bar(x_categories[i], data, bottom=bottom, color=colors[0])
        # bottom += data
        bottom = 0

    # Increase font size for all text elements
    plt.rcParams['font.size'] = 24
    plt.rcParams['font.weight'] = 'bold'
    plt.rcParams['font.serif'] = 'Times New Roman'

    # Make tick labels bigger and bold
    ax.tick_params(axis='both', which='major', labelsize=24, width=2)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontweight('bold')

    # Make axis labels bigger and bold
    ax.xaxis.label.set_size(28)
    ax.xaxis.label.set_weight('bold')
    ax.yaxis.label.set_size(28)
    ax.yaxis.label.set_weight('bold')
    # ax.errorbar(x_categories, y_data_list, yerr=y_data_list_std, fmt='none', ecolor='black', elinewidth=2, capsize=6)

    # Make legend bigger and bold
    # ax.legend(prop={'size': 14, 'weight': 'bold'})
    # ax.set_title('Stacked Histogram')
    ax.set_xlabel('Phone Type')
    ax.set_ylabel('Accuracy (%)')
    ax.set_yticks(np.arange(0, 101, 20))
    # ax.set_ylim(0, 10)
    # ax.yaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.xaxis.set_major_locator(plt.MultipleLocator(20))
    # ax.legend()
    # ax.legend(reversed(ax.get_legend_handles_labels()[0]), reversed(labels_stacked))
    
    return fig, ax

# Use existing data and add new series
# x_categories = ['10', '20', '30', '40', '50']
# y_data_list_stacked = [44.15, 24.17, 14.94, 10.90, 7.50]

x_categories = ["S10", "S22 Ultra", "Vivo", "OnePlus"]
y_data_list_stacked = [96.46, 97.87, 96.50, 96.77] 
# y_data_list_std= [0.30, 0.22, 0.25, 0.27, 0.33, ]
# Create the plot
fig, ax = plot_stacked_histogram(x_categories, y_data_list_stacked)

# Save the figure
plt.savefig('./paper_fig/Impact_phone.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
./Impact_noisy_levels/audio/路径下面存在很多wav语音文件，其中noise_audio_开头表示含噪语音，raw_audio_开头表示原始干净语音，rec_audio_开头则是通过算法增强的语音，它们名字最后一个_都跟着一个索引，代表是对应的语音。现在计算两个指标一个是noisy SISNR,即含噪的语音和原始语音的SISNR计算，然后计算算法增强后的语音和干净语音之间频谱的MCD值，最后将这两个指标放在一起，以SISNR从小到大排序，保存至./Impact_noisy_levels路径下的result.csv文件中，总共两列第一列为从小到大的SISNR值，第二列为对应的MCD值
